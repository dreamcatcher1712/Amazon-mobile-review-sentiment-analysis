# %% [markdown]
# # **Sentimental Analysis on Amazon mobile phone reviews**

# %% [markdown]
# Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

import nltk

# %% [markdown]
# Loading the dataset

# %%
df = pd.read_csv("/kaggle/input/amazon-mobile-phone-reviews/amazon_unlocked_mobile.csv")
print(df.shape)
# Out:
# (413840, 6)

# %% [markdown]
# Features of dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413840 entries, 0 to 413839
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   product_name  413840 non-null  object
#  1   brand_name    348669 non-null  object
#  2   price         407907 non-null  float64
#  3   rating        413840 non-null  int64
#  4   reviews       413770 non-null  object
#  5   review_votes  401544 non-null  float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 18.9+ MB

# %%
df.columns
# Out:
# Index(['product_name', 'brand_name', 'price', 'rating', 'reviews',
#        'review_votes'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# product_name        0
# brand_name      65171
# price            5933
# rating              0
# reviews            70
# review_votes    12296
# dtype: int64

# %% [markdown]
# Removing null values from dataset

# %%
df=df.dropna(axis=0)

# %%
df.isnull().sum()
# Out:
# product_name    0
# brand_name      0
# price           0
# rating          0
# reviews         0
# review_votes    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 334328 entries, 0 to 413839
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   product_name  334328 non-null  object
#  1   brand_name    334328 non-null  object
#  2   price         334328 non-null  float64
#  3   rating        334328 non-null  int64
#  4   reviews       334328 non-null  object
#  5   review_votes  334328 non-null  float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 17.9+ MB

# %%
df.head()
# Out:
#                                         product_name brand_name   price  \
# 0  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 1  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 2  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 3  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 4  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
#
#    rating                                            reviews  review_votes
# 0       5  I feel so LUCKY to have found this used (phone...           1.0
# 1       4  nice phone, nice up grade from my pantach revu...           0.0
# 2       5                                       Very pleased           0.0
# 3       4  It works good but it goes slow sometimes but i...           0.0
# 4       4  Great phone to replace my lost phone. The only...           0.0

# %% [markdown]
# Plotting on graph the top 3 mobile brands present in the dataset

# %%
value_counts = df['brand_name'].value_counts()
top_values = value_counts.head(3)
plt.figure(figsize=(10, 6)) 
top_values.plot(kind='bar', color='skyblue')
plt.xlabel('Unique Values')
plt.ylabel('Counts')
plt.title('Bar Graph of Unique Values in a Column')

plt.show()

# %% [markdown]
# Dividing the dataset into 3 parts, df1:brand name-Samsung; df2:brand name-BLU; df3:brand name-Apple

# %%
df1=df[df['brand_name'] == 'Samsung']

# %%
print(df1.shape)
# Out:
# (63035, 6)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 63035 entries, 0 to 413839
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_name  63035 non-null  object
#  1   brand_name    63035 non-null  object
#  2   price         63035 non-null  float64
#  3   rating        63035 non-null  int64
#  4   reviews       63035 non-null  object
#  5   review_votes  63035 non-null  float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 3.4+ MB

# %%
df2=df[df['brand_name'] == 'BLU']

# %%
print(df2.shape)
# Out:
# (59168, 6)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 59168 entries, 103014 to 410465
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_name  59168 non-null  object
#  1   brand_name    59168 non-null  object
#  2   price         59168 non-null  float64
#  3   rating        59168 non-null  int64
#  4   reviews       59168 non-null  object
#  5   review_votes  59168 non-null  float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 3.2+ MB

# %%
df3=df[df['brand_name'] == 'Apple']

# %%
print(df3.shape)
# Out:
# (56101, 6)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56101 entries, 3081 to 410277
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_name  56101 non-null  object
#  1   brand_name    56101 non-null  object
#  2   price         56101 non-null  float64
#  3   rating        56101 non-null  int64
#  4   reviews       56101 non-null  object
#  5   review_votes  56101 non-null  float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 3.0+ MB

# %% [markdown]
# Analysis on Samsung mobile reviews

# %%
df1.insert(0, 'id', range(1, len(df1) + 1))
df1 = df1.head(500)
print(df1.shape)
# Out:
# (500, 7)

# %%
df1.head()
# Out:
#    id                                       product_name brand_name   price  \
# 0   1  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 1   2  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 2   3  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 3   4  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 4   5  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
#
#    rating                                            reviews  review_votes
# 0       5  I feel so LUCKY to have found this used (phone...           1.0
# 1       4  nice phone, nice up grade from my pantach revu...           0.0
# 2       5                                       Very pleased           0.0
# 3       4  It works good but it goes slow sometimes but i...           0.0
# 4       4  Great phone to replace my lost phone. The only...           0.0

# %%
ax = df1['rating'].value_counts().sort_index() \
    .plot(kind='bar',
          title='Count of Reviews by Stars',
          figsize=(10, 5))
ax.set_xlabel('rating')
plt.show()

# %%
example = df1['reviews'][10]
print(example)
# Out:
# My fiance had this phone previously, but caused many problems. So, of course, we decided to browse amazon for a replacement til' our contract is up! & so far so good!

# %%
tokens = nltk.word_tokenize(example)
tokens[:10]
# Out:
# ['My',
#  'fiance',
#  'had',
#  'this',
#  'phone',
#  'previously',
#  ',',
#  'but',
#  'caused',
#  'many']

# %%
tagged = nltk.pos_tag(tokens)
tagged[:10]
# Out:
# [('My', 'PRP$'),
#  ('fiance', 'NN'),
#  ('had', 'VBD'),
#  ('this', 'DT'),
#  ('phone', 'NN'),
#  ('previously', 'RB'),
#  (',', ','),
#  ('but', 'CC'),
#  ('caused', 'VBD'),
#  ('many', 'JJ')]

# %%
entities = nltk.chunk.ne_chunk(tagged)
entities.pprint()
# Out:
# (S
#   My/PRP$
#   fiance/NN
#   had/VBD
#   this/DT
#   phone/NN
#   previously/RB
#   ,/,
#   but/CC
#   caused/VBD
#   many/JJ
#   problems/NNS
#   ./.
#   So/RB
#   ,/,
#   of/IN
#   course/NN
#   ,/,
#   we/PRP
#   decided/VBD
#   to/TO
#   browse/VB
#   amazon/NN
#   for/IN
#   a/DT
#   replacement/NN
#   til/NN
#   '/''
#   our/PRP$
#   contract/NN
#   is/VBZ
#   up/RP
#   !/.
#   &/CC
#   so/RB
#   far/RB
#   so/RB
#   good/JJ
#   !/.)

# %% [markdown]
# Model 1: Vader Sentiment Scoring

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

sia = SentimentIntensityAnalyzer()
# Out:
# /opt/conda/lib/python3.10/site-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
sia.polarity_scores('I am so happy!')
# Out:
# {'neg': 0.0, 'neu': 0.318, 'pos': 0.682, 'compound': 0.6468}

# %%
sia.polarity_scores('This is the worst thing ever.')
# Out:
# {'neg': 0.451, 'neu': 0.549, 'pos': 0.0, 'compound': -0.6249}

# %%
sia.polarity_scores(example)
# Out:
# {'neg': 0.094, 'neu': 0.688, 'pos': 0.218, 'compound': 0.6898}

# %%
res = {}
for i, row in tqdm(df1.iterrows(), total=len(df1)):
    text = row['reviews']
    myid = row['id']
    res[myid] = sia.polarity_scores(text)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
vaders1 = pd.DataFrame(res).T
vaders1 = vaders1.reset_index().rename(columns={'index': 'id'})
vaders1 = vaders1.merge(df1, how='left')

# %%
vaders1.to_csv('updated_dataset.csv', index=False)

# %%
vaders1.head()
# Out:
#    id    neg    neu    pos  compound  \
# 0   1  0.015  0.796  0.189    0.8783
# 1   2  0.072  0.597  0.331    0.9231
# 2   3  0.000  0.238  0.762    0.4927
# 3   4  0.000  0.500  0.500    0.9185
# 4   5  0.038  0.897  0.065    0.2942
#
#                                         product_name brand_name   price  \
# 0  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 1  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 2  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 3  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 4  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
#
#    rating                                            reviews  review_votes
# 0       5  I feel so LUCKY to have found this used (phone...           1.0
# 1       4  nice phone, nice up grade from my pantach revu...           0.0
# 2       5                                       Very pleased           0.0
# 3       4  It works good but it goes slow sometimes but i...           0.0
# 4       4  Great phone to replace my lost phone. The only...           0.0

# %%
ax = sns.barplot(data=vaders1, x='rating', y='compound')
ax.set_title('Compund Score by Amazon Star Review for Samsung mobile phones')
plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 3))
sns.barplot(data=vaders1, x='rating', y='pos', ax=axs[0])
sns.barplot(data=vaders1, x='rating', y='neu', ax=axs[1])
sns.barplot(data=vaders1, x='rating', y='neg', ax=axs[2])
axs[0].set_title('Positive')
axs[1].set_title('Neutral')
axs[2].set_title('Negative')
plt.tight_layout()
plt.show()

# %% [markdown]
# Roberta Model

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax
MODEL = f"cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)
# Out:
# Downloading config.json:   0%|          | 0.00/747 [00:00<?, ?B/s]
# Downloading vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]

# %%
print(example)
sia.polarity_scores(example)
# Out:
# My fiance had this phone previously, but caused many problems. So, of course, we decided to browse amazon for a replacement til' our contract is up! & so far so good!
# {'neg': 0.094, 'neu': 0.688, 'pos': 0.218, 'compound': 0.6898}

# %%
encoded_text = tokenizer(example, return_tensors='pt')
output = model(**encoded_text)
scores = output[0][0].detach().numpy()
scores = softmax(scores)
scores_dict = {
    'roberta_neg' : scores[0],
    'roberta_neu' : scores[1],
    'roberta_pos' : scores[2]
}
print(scores_dict)
# Out:
# {'roberta_neg': 0.11408841, 'roberta_neu': 0.2466663, 'roberta_pos': 0.63924533}

# %%
def polarity_scores_roberta(example):
    encoded_text = tokenizer(example, return_tensors='pt')
    output = model(**encoded_text)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    scores_dict = {
        'roberta_neg' : scores[0],
        'roberta_neu' : scores[1],
        'roberta_pos' : scores[2]
    }
    return scores_dict

# %%
res = {}
for i, row in tqdm(df1.iterrows(), total=len(df1)):
    try:
        text = row['reviews']
        myid = row['id']
        vader_result1 = sia.polarity_scores(text)
        vader_result1_rename = {}
        for key, value in vader_result1.items():
            vader_result1_rename[f"vader_{key}"] = value
        roberta_result1 = polarity_scores_roberta(text)
        both = {**vader_result1_rename, **roberta_result1}
        res[myid] = both
    except RuntimeError:
        print(f'Broke for id {myid}')
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
results_df1 = pd.DataFrame(res).T
results_df1 = results_df1.reset_index().rename(columns={'index': 'id'})
results_df1 = results_df1.merge(df1, how='left')

# %%
results_df1.columns
# Out:
# Index(['id', 'vader_neg', 'vader_neu', 'vader_pos', 'vader_compound',
#        'roberta_neg', 'roberta_neu', 'roberta_pos', 'product_name',
#        'brand_name', 'price', 'rating', 'reviews', 'review_votes'],
#       dtype='object')

# %%
x=sns.pairplot(data=results_df1,
             vars=['vader_neg', 'vader_neu', 'vader_pos',
                  'roberta_neg', 'roberta_neu', 'roberta_pos'],
            hue='rating',
            palette='tab10')
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Analysis on BLU mobile reviews

# %%
df2.insert(0, 'id', range(1, len(df2) + 1))
df2.head()
# Out:
#         id                                       product_name brand_name  \
# 103014   1  BLU Advance 4.0- Includes One Month Free Servi...        BLU
# 103015   2  BLU Advance 4.0- Includes One Month Free Servi...        BLU
# 103016   3  BLU Advance 4.0- Includes One Month Free Servi...        BLU
# 103017   4  BLU Advance 4.0- Includes One Month Free Servi...        BLU
# 103018   5  BLU Advance 4.0- Includes One Month Free Servi...        BLU
#
#         price  rating                                            reviews  \
# 103014   75.0       2  I bought this phone in May, and it has complet...
# 103015   75.0       5                                         Excellent.
# 103016   75.0       5                                        Great phone
# 103017   75.0       5  The screen is small, but works great. It is fa...
# 103018   75.0       2  i need to get rid of this phone...overheat pro...
#
#         review_votes
# 103014           0.0
# 103015           0.0
# 103016           0.0
# 103017           0.0
# 103018           0.0

# %%
ax = df2['rating'].value_counts().sort_index() \
    .plot(kind='bar',
          title='Count of Reviews by Stars',
          figsize=(10, 5))
ax.set_xlabel('rating')
plt.show()

# %%
df2.shape[0]
# Out:
# 59168

# %%
df2 = df2.head(500)
print(df2.shape)
# Out:
# (500, 7)

# %%
example1 = df2.iloc[12]['reviews']
print(example1)
# Out:
# i need to get rid of this phone...overheat problem... not quite nice.. sorry... don't recommend this.

# %%
tokens = nltk.word_tokenize(example1)
tokens[:10]
# Out:
# ['i', 'need', 'to', 'get', 'rid', 'of', 'this', 'phone', '...', 'overheat']

# %%
tagged = nltk.pos_tag(tokens)
tagged[:10]
# Out:
# [('i', 'NNS'),
#  ('need', 'VBP'),
#  ('to', 'TO'),
#  ('get', 'VB'),
#  ('rid', 'JJ'),
#  ('of', 'IN'),
#  ('this', 'DT'),
#  ('phone', 'NN'),
#  ('...', ':'),
#  ('overheat', 'NN')]

# %%
entities = nltk.chunk.ne_chunk(tagged)
entities.pprint()
# Out:
# (S
#   i/NNS
#   need/VBP
#   to/TO
#   get/VB
#   rid/JJ
#   of/IN
#   this/DT
#   phone/NN
#   .../:
#   overheat/NN
#   problem/NN
#   .../:
#   not/RB
#   quite/RB
#   nice../JJ
#   sorry/NN
#   .../:
#   do/VBP
#   n't/RB
#   recommend/VB
#   this/DT
#   ./.)

# %%
sia.polarity_scores(example1)
# Out:
# {'neg': 0.131, 'neu': 0.869, 'pos': 0.0, 'compound': -0.2755}

# %%
res1 = {}
for i, row in tqdm(df2.iterrows(), total=len(df2)):
    text = row['reviews']
    myid = row['id']
    res1[myid] = sia.polarity_scores(text)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
vaders2 = pd.DataFrame(res1).T
vaders2 = vaders2.reset_index().rename(columns={'index': 'id'})
vaders2 = vaders2.merge(df2, how='left')

# %%
vaders2.to_csv('updated_dataset1.csv', index=False)

# %%
vaders2.head()
# Out:
#    id    neg    neu    pos  compound  \
# 0   1  0.074  0.816  0.109    0.8708
# 1   2  0.000  0.000  1.000    0.5719
# 2   3  0.000  0.196  0.804    0.6249
# 3   4  0.000  0.827  0.173    0.7684
# 4   5  0.131  0.869  0.000   -0.2755
#
#                                         product_name brand_name  price  \
# 0  BLU Advance 4.0- Includes One Month Free Servi...        BLU   75.0
# 1  BLU Advance 4.0- Includes One Month Free Servi...        BLU   75.0
# 2  BLU Advance 4.0- Includes One Month Free Servi...        BLU   75.0
# 3  BLU Advance 4.0- Includes One Month Free Servi...        BLU   75.0
# 4  BLU Advance 4.0- Includes One Month Free Servi...        BLU   75.0
#
#    rating                                            reviews  review_votes
# 0       2  I bought this phone in May, and it has complet...           0.0
# 1       5                                         Excellent.           0.0
# 2       5                                        Great phone           0.0
# 3       5  The screen is small, but works great. It is fa...           0.0
# 4       2  i need to get rid of this phone...overheat pro...           0.0

# %%
ax1 = sns.barplot(data=vaders2, x='rating', y='compound')
ax1.set_title('Compund Score by Amazon Star Review for BLU mobile phones')
plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 3))
sns.barplot(data=vaders2, x='rating', y='pos', ax=axs[0])
sns.barplot(data=vaders2, x='rating', y='neu', ax=axs[1])
sns.barplot(data=vaders2, x='rating', y='neg', ax=axs[2])
axs[0].set_title('Positive')
axs[1].set_title('Neutral')
axs[2].set_title('Negative')
plt.tight_layout()
plt.show()

# %%
encoded_text1 = tokenizer(example1, return_tensors='pt')
output = model(**encoded_text1)
scores = output[0][0].detach().numpy()
scores = softmax(scores)
scores_dict1 = {
    'roberta_neg' : scores[0],
    'roberta_neu' : scores[1],
    'roberta_pos' : scores[2]
}
print(scores_dict1)
# Out:
# {'roberta_neg': 0.97107095, 'roberta_neu': 0.025040628, 'roberta_pos': 0.0038883567}

# %%
def polarity_scores_roberta(example1):
    encoded_text1 = tokenizer(example1, return_tensors='pt')
    output = model(**encoded_text1)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    scores_dict1 = {
        'roberta_neg' : scores[0],
        'roberta_neu' : scores[1],
        'roberta_pos' : scores[2]
    }
    return scores_dict1

# %%
res1 = {}
for i, row in tqdm(df2.iterrows(), total=len(df2)):
    try:
        text = row['reviews']
        myid = row['id']
        vader_result2 = sia.polarity_scores(text)
        vader_result2_rename = {}
        for key, value in vader_result2.items():
            vader_result2_rename[f"vader_{key}"] = value
        roberta_result2 = polarity_scores_roberta(text)
        both = {**vader_result2_rename, **roberta_result2}
        res1[myid] = both
    except RuntimeError:
        print(f'Broke for id {myid}')
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
results_df2 = pd.DataFrame(res1).T
results_df2 = results_df2.reset_index().rename(columns={'index': 'id'})
results_df2 = results_df2.merge(df2, how='left')

# %%
results_df2.columns
# Out:
# Index(['id', 'vader_neg', 'vader_neu', 'vader_pos', 'vader_compound',
#        'roberta_neg', 'roberta_neu', 'roberta_pos', 'product_name',
#        'brand_name', 'price', 'rating', 'reviews', 'review_votes'],
#       dtype='object')

# %%
x=sns.pairplot(data=results_df2,
             vars=['vader_neg', 'vader_neu', 'vader_pos',
                  'roberta_neg', 'roberta_neu', 'roberta_pos'],
            hue='rating',
            palette='tab10')
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Analysis on Apple mobile reviews

# %%
df3.insert(0, 'id', range(1, len(df3) + 1))
df3.head()
# Out:
#       id                                       product_name brand_name  price  \
# 3081   1  Apple - Iphone 5c A1532 Verizon 16 GB Cell Pho...      Apple   33.0
# 3082   2  Apple - Iphone 5c A1532 Verizon 16 GB Cell Pho...      Apple   33.0
# 3083   3  Apple - Iphone 5c A1532 Verizon 16 GB Cell Pho...      Apple   33.0
# 3084   4  Apple - Iphone 5c A1532 Verizon 16 GB Cell Pho...      Apple   33.0
# 3085   5  Apple - Iphone 5c A1532 Verizon 16 GB Cell Pho...      Apple   33.0
#
#       rating                                            reviews  review_votes
# 3081       5  Was a gift for my husband and he loves it. Rep...           5.0
# 3082       5  Great price, extremely fast shipping works as ...           1.0
# 3083       4  Moving from Android to Apple...my kids have th...           1.0
# 3084       4  It is compatible with Verizon. Not pink but PE...           0.0
# 3085       5              I love this phone! Thank you so much.           1.0

# %%
ax = df3['rating'].value_counts().sort_index() \
    .plot(kind='bar',
          title='Count of Reviews by Stars',
          figsize=(10, 5))
ax.set_xlabel('rating')
plt.show()

# %%
df3.shape[0]
df3 = df3.head(500)
print(df3.shape)
# Out:
# (500, 7)

# %%
example2 = df3.iloc[20]['reviews']
print(example2)
# Out:
# After reviewing the phone and trying everything ywsteady to switch over to this phone it would not work. I ordered a new sim as well. Long story short, boh were a waste of my time and money and the phone did not come with a charger. The phone itself is in great condition, but was a waste for me.

# %%
tokens = nltk.word_tokenize(example2)
tokens[:10]
# Out:
# ['After',
#  'reviewing',
#  'the',
#  'phone',
#  'and',
#  'trying',
#  'everything',
#  'ywsteady',
#  'to',
#  'switch']

# %%
tagged = nltk.pos_tag(tokens)
tagged[:10]
# Out:
# [('After', 'IN'),
#  ('reviewing', 'VBG'),
#  ('the', 'DT'),
#  ('phone', 'NN'),
#  ('and', 'CC'),
#  ('trying', 'VBG'),
#  ('everything', 'NN'),
#  ('ywsteady', 'NN'),
#  ('to', 'TO'),
#  ('switch', 'VB')]

# %%
entities = nltk.chunk.ne_chunk(tagged)
entities.pprint()
# Out:
# (S
#   After/IN
#   reviewing/VBG
#   the/DT
#   phone/NN
#   and/CC
#   trying/VBG
#   everything/NN
#   ywsteady/NN
#   to/TO
#   switch/VB
#   over/IN
#   to/TO
#   this/DT
#   phone/NN
#   it/PRP
#   would/MD
#   not/RB
#   work/VB
#   ./.
#   I/PRP
#   ordered/VBD
#   a/DT
#   new/JJ
#   sim/NN
#   as/RB
#   well/RB
#   ./.
#   (GPE Long/NNP)
#   story/NN
#   short/JJ
#   ,/,
#   boh/EX
#   were/VBD
#   a/DT
#   waste/NN
#   of/IN
#   my/PRP$
#   time/NN
#   and/CC
#   money/NN
#   and/CC
#   the/DT
#   phone/NN
#   did/VBD
#   not/RB
#   come/VBN
#   with/IN
#   a/DT
#   charger/NN
#   ./.
#   The/DT
#   phone/NN
#   itself/PRP
#   is/VBZ
#   in/IN
#   great/JJ
#   condition/NN
#   ,/,
#   but/CC
#   was/VBD
#   a/DT
#   waste/NN
#   for/IN
#   me/PRP
#   ./.)

# %%
sia.polarity_scores(example2)
# Out:
# {'neg': 0.094, 'neu': 0.838, 'pos': 0.069, 'compound': -0.3612}

# %%
res2 = {}
for i, row in tqdm(df3.iterrows(), total=len(df3)):
    text = row['reviews']
    myid = row['id']
    res2[myid] = sia.polarity_scores(text)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
vaders3 = pd.DataFrame(res2).T
vaders3 = vaders3.reset_index().rename(columns={'index': 'id'})
vaders3 = vaders3.merge(df3, how='left')

# %%
vaders3.to_csv('updated_dataset2.csv', index=False)

# %%
vaders3.head()
# Out:
#    id    neg    neu    pos  compound  \
# 0   1  0.159  0.765  0.076   -0.6836
# 1   2  0.000  0.614  0.386    0.6588
# 2   3  0.000  0.869  0.131    0.8074
# 3   4  0.124  0.593  0.283    0.8143
# 4   5  0.000  0.417  0.583    0.7901
#
#                                         product_name brand_name  price  \
# 0  Apple - Iphone 5c A1532 Verizon 16 GB Cell Pho...      Apple   33.0
# 1  Apple - Iphone 5c A1532 Verizon 16 GB Cell Pho...      Apple   33.0
# 2  Apple - Iphone 5c A1532 Verizon 16 GB Cell Pho...      Apple   33.0
# 3  Apple - Iphone 5c A1532 Verizon 16 GB Cell Pho...      Apple   33.0
# 4  Apple - Iphone 5c A1532 Verizon 16 GB Cell Pho...      Apple   33.0
#
#    rating                                            reviews  review_votes
# 0       5  Was a gift for my husband and he loves it. Rep...           5.0
# 1       5  Great price, extremely fast shipping works as ...           1.0
# 2       4  Moving from Android to Apple...my kids have th...           1.0
# 3       4  It is compatible with Verizon. Not pink but PE...           0.0
# 4       5              I love this phone! Thank you so much.           1.0

# %%
ax2 = sns.barplot(data=vaders3, x='rating', y='compound')
ax2.set_title('Compund Score by Amazon Star Review for Apple mobile phones')
plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 3))
sns.barplot(data=vaders3, x='rating', y='pos', ax=axs[0])
sns.barplot(data=vaders3, x='rating', y='neu', ax=axs[1])
sns.barplot(data=vaders3, x='rating', y='neg', ax=axs[2])
axs[0].set_title('Positive')
axs[1].set_title('Neutral')
axs[2].set_title('Negative')
plt.tight_layout()
plt.show()

# %%
encoded_text2 = tokenizer(example2, return_tensors='pt')
output = model(**encoded_text2)
scores = output[0][0].detach().numpy()
scores = softmax(scores)
scores_dict2 = {
    'roberta_neg' : scores[0],
    'roberta_neu' : scores[1],
    'roberta_pos' : scores[2]
}
print(scores_dict2)
# Out:
# {'roberta_neg': 0.8859142, 'roberta_neu': 0.09729014, 'roberta_pos': 0.01679563}

# %%
def polarity_scores_roberta(example2):
    encoded_text2 = tokenizer(example2, return_tensors='pt')
    output = model(**encoded_text2)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    scores_dict2 = {
        'roberta_neg' : scores[0],
        'roberta_neu' : scores[1],
        'roberta_pos' : scores[2]
    }
    return scores_dict2

# %%
res2 = {}
for i, row in tqdm(df3.iterrows(), total=len(df3)):
    try:
        text = row['reviews']
        myid = row['id']
        vader_result3 = sia.polarity_scores(text)
        vader_result3_rename = {}
        for key, value in vader_result3.items():
            vader_result3_rename[f"vader_{key}"] = value
        roberta_result3 = polarity_scores_roberta(text)
        both = {**vader_result3_rename, **roberta_result3}
        res2[myid] = both
    except RuntimeError:
        print(f'Broke for id {myid}')
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
results_df3 = pd.DataFrame(res2).T
results_df3 = results_df3.reset_index().rename(columns={'index': 'id'})
results_df3 = results_df3.merge(df3, how='left')

# %%
results_df3.columns
# Out:
# Index(['id', 'vader_neg', 'vader_neu', 'vader_pos', 'vader_compound',
#        'roberta_neg', 'roberta_neu', 'roberta_pos', 'product_name',
#        'brand_name', 'price', 'rating', 'reviews', 'review_votes'],
#       dtype='object')

# %%
x=sns.pairplot(data=results_df3,
             vars=['vader_neg', 'vader_neu', 'vader_pos',
                  'roberta_neg', 'roberta_neu', 'roberta_pos'],
            hue='rating',
            palette='tab10')
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Comparison of all 3 mobile reviews

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 3))
sns.barplot(data=vaders1, x='rating', y='compound', ax=axs[0])
sns.barplot(data=vaders2, x='rating', y='compound', ax=axs[1])
sns.barplot(data=vaders3, x='rating', y='compound', ax=axs[2])
axs[0].set_title('CS for Samsung mobile phones')
axs[1].set_title('CS for BLU mobile phones')
axs[2].set_title('CS for Apple mobile phones')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Your dataframes vaders1, vaders2, and vaders3 should already be defined.

# Calculate the sum of 'pos' for each dataframe
total_pos1 = vaders1['pos'].sum()
total_pos11 = results_df1['roberta_pos'].sum()
total_pos2 = vaders2['pos'].sum()
total_pos22 = results_df2['roberta_pos'].sum()
total_pos3 = vaders3['pos'].sum()
total_pos33 = results_df3['roberta_pos'].sum()

# Create data for the pie chart
posvader_counts = [total_pos1, total_pos2, total_pos3]
posroberta_counts = [total_pos11, total_pos22, total_pos33]
labels = ['Samsung', 'BLU', 'Apple']
colors = ['gold', 'lightcoral', 'lightskyblue']
explode = (0, 0, 0)  # Explode the first slice (Samsung)

plt.figure(figsize=(18, 6))

plt.subplot(131)
plt.pie(posvader_counts, labels=labels, colors=colors, explode=explode, autopct='%1.1f%%', startangle=140)
plt.title('Vader positive Sentiment Distribution')

plt.subplot(132)
plt.pie(posroberta_counts, labels=labels, colors=colors, explode=explode, autopct='%1.1f%%', startangle=140)
plt.title('Roberta positive Sentiment Distribution')

plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt

# Your dataframes vaders1, vaders2, and vaders3 should already be defined.

# Calculate the sum of 'pos' for each dataframe
total_pos1 = vaders1['neg'].sum()
total_pos11 = results_df1['roberta_neg'].sum()
total_pos2 = vaders2['neg'].sum()
total_pos22 = results_df2['roberta_neg'].sum()
total_pos3 = vaders3['neg'].sum()
total_pos33 = results_df3['roberta_neg'].sum()

# Create data for the pie chart
posvader_counts = [total_pos1, total_pos2, total_pos3]
posroberta_counts = [total_pos11, total_pos22, total_pos33]
labels = ['Samsung', 'BLU', 'Apple']
colors = ['gold', 'lightcoral', 'lightskyblue']
explode = (0, 0, 0)  # Explode the first slice (Samsung)

plt.figure(figsize=(18, 6))

plt.subplot(131)
plt.pie(posvader_counts, labels=labels, colors=colors, explode=explode, autopct='%1.1f%%', startangle=140)
plt.title('Vader negative Sentiment Distribution')

plt.subplot(132)
plt.pie(posroberta_counts, labels=labels, colors=colors, explode=explode, autopct='%1.1f%%', startangle=140)
plt.title('Roberta negative Sentiment Distribution')

plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt

total_pos1 = vaders1['neu'].sum()
total_pos11 = results_df1['roberta_neu'].sum()
total_pos2 = vaders2['neu'].sum()
total_pos22 = results_df2['roberta_neu'].sum()
total_pos3 = vaders3['neu'].sum()
total_pos33 = results_df3['roberta_neu'].sum()

posvader_counts = [total_pos1, total_pos2, total_pos3]
posroberta_counts = [total_pos11, total_pos22, total_pos33]
labels = ['Samsung', 'BLU', 'Apple']
colors = ['gold', 'lightcoral', 'lightskyblue']
explode = (0, 0, 0)  

plt.figure(figsize=(18, 6))

plt.subplot(131)
plt.pie(posvader_counts, labels=labels, colors=colors, explode=explode, autopct='%1.1f%%', startangle=140)
plt.title('Vader neutral Sentiment Distribution')

plt.subplot(132)
plt.pie(posroberta_counts, labels=labels, colors=colors, explode=explode, autopct='%1.1f%%', startangle=140)
plt.title('Roberta neutral Sentiment Distribution')

plt.tight_layout()

plt.show()
